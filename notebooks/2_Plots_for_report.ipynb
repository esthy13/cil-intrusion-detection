# %% [markdown]
# # Plots for the report

# %%
from google.colab import userdata
token = userdata.get('GIT_TOKEN')
username = userdata.get('USERNAME')
email = userdata.get('EMAIL')
# !git config --global user.email {email}
# !git config --global user.name {username}
repo = "cil-intrusion-detection"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# %cd {repo}
# !git config pull.rebase false # if you need to do some merging
# !git pull origin main
# Out:
# fatal: destination path 'cil-intrusion-detection' already exists and is not an empty directory.
# /content/cil-intrusion-detection
# From https://github.com/esthy13/cil-intrusion-detection
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# ## Bar plot

# %%
from src.plots import bar_plot
bar_plot(target_scenario_pattern=[1,1,1,1,1,1,1])

# %% [markdown]
# ## Line plot

# %%
from src.plots import line_plot
line_plot()

# %%
commit_message = "plotting methods tested" # @param {type:"string"}
# !git remote set-url origin https://{token}@github.com/esthy13/cil-intrusion-detection.git
# !git add .
# !git status
# !git commit -m "$commit_message"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   src/plots.py
#
# [main 6d8c8df] plotting methods tested
#  1 file changed, 30 insertions(+), 25 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 840 bytes | 840.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/esthy13/cil-intrusion-detection.git
#    d4404fc..6d8c8df  main -> main

# %% [markdown]
# restart session if you want to rerun the notebook from the begin (otherwise why would you like to rerun the notebook??)
