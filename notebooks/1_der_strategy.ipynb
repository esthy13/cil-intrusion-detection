# %% [markdown]
# <a href="https://colab.research.google.com/github/esthy13/cil-intrusion-detection/blob/main/notebooks/1_der_strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DER++ for Intrusion Detection (CIC-IDS)
#
# Minimal **working** implementation of **Dark Experience Replay++**
# for class-incremental intrusion detection.

# %%
from google.colab import userdata
token = userdata.get('GIT_TOKEN')
username = userdata.get('USERNAME')
email = userdata.get('EMAIL')
# !git config --global user.email {email}
# !git config --global user.name {username}
repo = "cil-intrusion-detection"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# %cd {repo}
# !git config pull.rebase false # if you need to do some merging
# !git pull origin main
# Out:
# Cloning into 'cil-intrusion-detection'...
# remote: Enumerating objects: 1529, done.
# remote: Counting objects: 100% (252/252), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 1529 (delta 220), reused 199 (delta 190), pack-reused 1277 (from 1)
# Receiving objects: 100% (1529/1529), 200.80 MiB | 29.79 MiB/s, done.
# Resolving deltas: 100% (792/792), done.
# /content/cil-intrusion-detection/cil-intrusion-detection
# From https://github.com/esthy13/cil-intrusion-detection
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python main.py \
  --strategy der \
  --dataset 2015 \
  --scenarios 1+1+1+1+1+1+1+1 2+2+4 4+4 \
  --epochs 5 \
  --memory_size 5000 \
  --batch_size 256 \
  --lr 1e-3
# Out:
# Strategy der ========
#
#
# === Scenario - [1, 1, 1, 1, 1, 1, 1, 1] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['Normal', 'Generic']
#     Seen so far: []
#
#     accuracy: 0.98
#     attack_accuracy: 0.97
#
#    --- Task 2 ---
#
#     New attacks: ['Exploits']
#     Seen so far: ['Normal', 'Generic']
#
#     accuracy: 0.95
#     attack_accuracy: 0.94
#
#    --- Task 3 ---
#
#     New attacks: ['Fuzzers']
#     Seen so far: ['Normal', 'Generic', 'Exploits']
#
#     accuracy: 0.84
#     attack_accuracy: 0.83
#
#    --- Task 4 ---
#
#     New attacks: ['DoS']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers']
#
#     accuracy: 0.77
#     attack_accuracy: 0.77
#
#    --- Task 5 ---
#
#     New attacks: ['Reconnaissance']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS']
#
#     accuracy: 0.76
#     attack_accuracy: 0.70
#
#    --- Task 6 ---
#
#     New attacks: ['Analysis']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS', 'Reconnaissance']
#
#     accuracy: 0.77
#     attack_accuracy: 0.71
#
#    --- Task 7 ---
#
#     New attacks: ['Backdoor']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS', 'Reconnaissance', 'Analysis']
#
#     accuracy: 0.75
#     attack_accuracy: 0.69
#
#    --- Task 8 ---
#
#     New attacks: ['Shellcode']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS', 'Reconnaissance', 'Analysis', 'Backdoor']
#
#     accuracy: 0.76
#     attack_accuracy: 0.70
#
# Forgetting measure: 0.39
# Forgetting attack measure: 0.37
# Average accuracy: 0.82
# Average attack accuracy: 0.79
#
# === Scenario - [2, 2, 4] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['Normal', 'Generic', 'Exploits']
#     Seen so far: []
#
#     accuracy: 0.94
#     attack_accuracy: 0.95
#
#    --- Task 2 ---
#
#     New attacks: ['Fuzzers', 'DoS']
#     Seen so far: ['Normal', 'Generic', 'Exploits']
#
#     accuracy: 0.79
#     attack_accuracy: 0.74
#
#    --- Task 3 ---
#
#     New attacks: ['Reconnaissance', 'Analysis', 'Backdoor', 'Shellcode']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS']
#
#     accuracy: 0.77
#     attack_accuracy: 0.68
#
# Forgetting measure: 0.21
# Forgetting attack measure: 0.23
# Average accuracy: 0.84
# Average attack accuracy: 0.79
#
# === Scenario - [4, 4] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS']
#     Seen so far: []
#
#     accuracy: 0.80
#     attack_accuracy: 0.72
#
#    --- Task 2 ---
#
#     New attacks: ['Reconnaissance', 'Analysis', 'Backdoor', 'Shellcode']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS']
#
#     accuracy: 0.75
#     attack_accuracy: 0.71
#
# Forgetting measure: 0.04
# Forgetting attack measure: -0.01
# Average accuracy: 0.78
# Average attack accuracy: 0.72

# %%
# !python main.py \
  --strategy der \
  --dataset 2017 \
  --scenarios 1+1+1+1+1+1+1 2+2+3 3+4 \
  --epochs 5 \
  --memory_size 5000 \
  --batch_size 256 \
  --lr 1e-3
# Out:
# Strategy der ========
#
#
# === Scenario - [1, 1, 1, 1, 1, 1, 1] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['benign', 'dos']
#     Seen so far: []
#
#     accuracy: 0.90
#     attack_accuracy: 0.03
#
#    --- Task 2 ---
#
#     New attacks: ['portscan']
#     Seen so far: ['benign', 'dos']
#
#     accuracy: 0.88
#     attack_accuracy: 0.22
#
#    --- Task 3 ---
#
#     New attacks: ['ddos']
#     Seen so far: ['benign', 'dos', 'portscan']
#
#     accuracy: 0.94
#     attack_accuracy: 0.71
#
#    --- Task 4 ---
#
#     New attacks: ['ftp-patator']
#     Seen so far: ['benign', 'dos', 'portscan', 'ddos']
#
#     accuracy: 0.93
#     attack_accuracy: 0.67
#
#    --- Task 5 ---
#
#     New attacks: ['ssh-patator']
#     Seen so far: ['benign', 'dos', 'portscan', 'ddos', 'ftp-patator']
#
#     accuracy: 0.95
#     attack_accuracy: 0.76
#
#    --- Task 6 ---
#
#     New attacks: ['web-attack']
#     Seen so far: ['benign', 'dos', 'portscan', 'ddos', 'ftp-patator', 'ssh-patator']
#
#     accuracy: 0.92
#     attack_accuracy: 0.61
#
#    --- Task 7 ---
#
#     New attacks: ['bot']
#     Seen so far: ['benign', 'dos', 'portscan', 'ddos', 'ftp-patator', 'ssh-patator', 'web-attack']
#
#     accuracy: 0.94
#     attack_accuracy: 0.72
#
# Forgetting measure: 0.32
# Forgetting attack measure: 0.09
# Average accuracy: 0.92
# Average attack accuracy: 0.53
#
# === Scenario - [2, 2, 3] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['benign', 'dos', 'portscan']
#     Seen so far: []
#
#     accuracy: 0.87
#     attack_accuracy: 0.18
#
#    --- Task 2 ---
#
#     New attacks: ['ddos', 'ftp-patator']
#     Seen so far: ['benign', 'dos', 'portscan']
#
#     accuracy: 0.89
#     attack_accuracy: 0.44
#
#    --- Task 3 ---
#
#     New attacks: ['ssh-patator', 'web-attack', 'bot']
#     Seen so far: ['benign', 'dos', 'portscan', 'ddos', 'ftp-patator']
#
#     accuracy: 0.94
#     attack_accuracy: 0.71
#
# Forgetting measure: 0.11
# Forgetting attack measure: -0.18
# Average accuracy: 0.90
# Average attack accuracy: 0.44
#
# === Scenario - [3, 4] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['benign', 'dos', 'portscan', 'ddos']
#     Seen so far: []
#
#     accuracy: 0.87
#     attack_accuracy: 0.36
#
#    --- Task 2 ---
#
#     New attacks: ['ftp-patator', 'ssh-patator', 'web-attack', 'bot']
#     Seen so far: ['benign', 'dos', 'portscan', 'ddos']
#
#     accuracy: 0.93
#     attack_accuracy: 0.68
#
# Forgetting measure: -0.06
# Forgetting attack measure: -0.32
# Average accuracy: 0.90
# Average attack accuracy: 0.52

# %% [markdown]
# Negative forgetting is normal and indicates backward transfer: learning new tasks helped the model perform better on old tasks.

# %%
commit_message = "saving der training results" # @param {type:"string"}
# !git remote set-url origin https://{token}@github.com/esthy13/cil-intrusion-detection.git
# !git add .
# !git status
# !git commit -m "$commit_message"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# %cd ..
# Out:
# /content
