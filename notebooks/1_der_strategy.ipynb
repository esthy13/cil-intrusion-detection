# %% [markdown]
# <a href="https://colab.research.google.com/github/esthy13/cil-intrusion-detection/blob/main/notebooks/1_der_strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DER++ for Intrusion Detection (CIC-IDS)
#
# Minimal **working** implementation of **Dark Experience Replay++**
# for class-incremental intrusion detection.

# %%
from google.colab import userdata
token = userdata.get('GIT_TOKEN')
username = userdata.get('USERNAME')
email = userdata.get('EMAIL')
# !git config --global user.email {email}
# !git config --global user.name {username}
repo = "cil-intrusion-detection"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# %cd {repo}
# !git config pull.rebase false # if you need to do some merging
# !git pull origin main
# Out:
# fatal: destination path 'cil-intrusion-detection' already exists and is not an empty directory.
# /content/cil-intrusion-detection
# From https://github.com/esthy13/cil-intrusion-detection
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python main.py --strategy der --dataset 2017 --scenarios 3+4 --epochs 5 --memory_size 2000
# Out:
# Strategy der ========
#
#
# === Scenario - [3, 4] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['benign', 'dos', 'portscan', 'ddos']
#     Seen so far: []
#
#     accuracy: 0.87
#     attack_accuracy: 0.33
#
#    --- Task 2 ---
#
#     New attacks: ['ftp-patator', 'ssh-patator', 'web-attack', 'bot']
#     Seen so far: ['benign', 'dos', 'portscan', 'ddos']
#
#     accuracy: 0.93
#     attack_accuracy: 0.66
#
# Forgetting measure: -0.06
# Forgetting attack measure: -0.33
# Average accuracy: 0.90
# Average attack accuracy: 0.49

# %%
# !python main.py --strategy der --dataset 2015 --scenarios 4+4 --epochs 5 --memory_size 2000
# Out:
# Strategy der ========
#
#
# === Scenario - [4, 4] ===
#
#
#    --- Task 1 ---
#
#     New attacks: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS']
#     Seen so far: []
#
#     accuracy: 0.78
#     attack_accuracy: 0.70
#
#    --- Task 2 ---
#
#     New attacks: ['Reconnaissance', 'Analysis', 'Backdoor', 'Shellcode']
#     Seen so far: ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS']
#
#     accuracy: 0.70
#     attack_accuracy: 0.73
#
# Forgetting measure: 0.06
# Forgetting attack measure: -0.04
# Average accuracy: 0.74
# Average attack accuracy: 0.72

# %% [markdown]
# Negative forgetting is normal and indicates backward transfer: learning new tasks helped the model perform better on old tasks.

# %%
commit_message = "checking that also 2015 dataset works with der" # @param {type:"string"}
# !git remote set-url origin https://{token}@github.com/esthy13/cil-intrusion-detection.git
# !git add .
# !git status
# !git commit -m "$commit_message"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   results/training/2015_DER++_[4, 4].json
# 	modified:   results/weights/DER_scenario0_task0.weights.h5
# 	modified:   results/weights/DER_scenario0_task1.weights.h5
#
# [main 683d140] checking that also 2015 dataset works with der
#  3 files changed, 34 insertions(+)
#  create mode 100644 results/training/2015_DER++_[4, 4].json
#  rewrite results/weights/DER_scenario0_task0.weights.h5 (94%)
#  rewrite results/weights/DER_scenario0_task1.weights.h5 (94%)
# Enumerating objects: 14, done.
# Counting objects: 100% (14/14), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 615.98 KiB | 16.21 MiB/s, done.
# Total 8 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/esthy13/cil-intrusion-detection.git
#    7409e77..683d140  main -> main

# %%
# %cd ..
# Out:
# /content
