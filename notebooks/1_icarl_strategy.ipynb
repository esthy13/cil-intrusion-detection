# %% [markdown]
# <a href="https://colab.research.google.com/github/esthy13/cil-intrusion-detection/blob/main/notebooks/1_icarl_strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DER++ for Intrusion Detection (CIC-IDS)
#
# Minimal **working** implementation of **Dark Experience Replay++**
# for class-incremental intrusion detection.

# %%
from google.colab import userdata
token = userdata.get('GIT_TOKEN')
username = userdata.get('USERNAME')
email = userdata.get('EMAIL')
# !git config --global user.email {email}
# !git config --global user.name {username}
repo = "cil-intrusion-detection"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# %cd {repo}
# !git config pull.rebase false # if you need to do some merging
# !git pull origin main
# Out:
# fatal: destination path 'cil-intrusion-detection' already exists and is not an empty directory.
# /content/cil-intrusion-detection
# From https://github.com/esthy13/cil-intrusion-detection
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python main.py \
  --strategy icarl \
  --dataset 2015 \
  --scenarios 1+1+1+1+1+1+1+1 2+2+4 4+4 \
  --epochs 5 \
  --memory_size 5000 \
  --batch_size 256 \
  --lr 1e-3
# Out:
# === Strategy icarl - attack pattern [1, 1, 1, 1, 1, 1, 1, 1] ===
#
# Task 1 - new attacks: ['Normal', 'Generic']
#
#
# Epoch 1/5: 100% 375/375 [00:02<00:00, 126.59it/s, loss=0.0272]
# Epoch 1 | Avg Loss: 0.0453
# Epoch 2/5: 100% 375/375 [00:03<00:00, 122.96it/s, loss=0.0204]
# Epoch 2 | Avg Loss: 0.0151
# Epoch 3/5: 100% 375/375 [00:03<00:00, 111.85it/s, loss=0.00425]
# Epoch 3 | Avg Loss: 0.0128
# Epoch 4/5: 100% 375/375 [00:02<00:00, 135.65it/s, loss=0.00142]
# Epoch 4 | Avg Loss: 0.0117
# Epoch 5/5: 100% 375/375 [00:02<00:00, 137.87it/s, loss=0.00198]
# Epoch 5 | Avg Loss: 0.0111
# Task 2 - new attacks: ['Exploits']
#
#
# Epoch 1/5: 100% 150/150 [00:01<00:00, 115.05it/s, loss=0.0854]
# Epoch 1 | Avg Loss: 0.1762
# Epoch 2/5: 100% 150/150 [00:01<00:00, 135.23it/s, loss=0.0968]
# Epoch 2 | Avg Loss: 0.0760
# Epoch 3/5: 100% 150/150 [00:01<00:00, 135.53it/s, loss=0.0215]
# Epoch 3 | Avg Loss: 0.0634
# Epoch 4/5: 100% 150/150 [00:01<00:00, 135.10it/s, loss=0.0151]
# ...

# %%
# !python main.py \
  --strategy icarl \
  --dataset 2017 \
  --scenarios 1+1+1+1+1+1+1 2+2+3 3+4 \
  --epochs 5 \
  --memory_size 5000 \
  --batch_size 256 \
  --lr 1e-3
# Out:
# === Strategy icarl - attack pattern [1, 1, 1, 1, 1, 1, 1] ===
#
# Task 1 - new attacks: ['benign', 'dos']
#
#
# Epoch 1/5: 100% 690/690 [00:04<00:00, 150.63it/s, loss=0.048]
# Epoch 1 | Avg Loss: 0.1057
# Epoch 2/5: 100% 690/690 [00:05<00:00, 129.89it/s, loss=0.0503]
# Epoch 2 | Avg Loss: 0.0582
# Epoch 3/5: 100% 690/690 [00:04<00:00, 159.06it/s, loss=0.0267]
# Epoch 3 | Avg Loss: 0.0439
# Epoch 4/5: 100% 690/690 [00:04<00:00, 150.40it/s, loss=0.032]
# Epoch 4 | Avg Loss: 0.0319
# Epoch 5/5: 100% 690/690 [00:05<00:00, 136.41it/s, loss=0.0336]
# Epoch 5 | Avg Loss: 0.0267
# Task 2 - new attacks: ['portscan']
#
#
# Epoch 1/5: 100% 63/63 [00:00<00:00, 95.27it/s, loss=1.92]
# Epoch 1 | Avg Loss: 4.1539
# Epoch 2/5: 100% 63/63 [00:00<00:00, 129.64it/s, loss=0.368]
# Epoch 2 | Avg Loss: 0.8928
# Epoch 3/5: 100% 63/63 [00:00<00:00, 124.98it/s, loss=0.146]
# Epoch 3 | Avg Loss: 0.2029
# Epoch 4/5: 100% 63/63 [00:00<00:00, 132.10it/s, loss=0.059]
# Epoch 4 | Avg Loss: 0.1161
# ...

# %% [markdown]
# Negative forgetting is normal and indicates backward transfer: learning new tasks helped the model perform better on old tasks.

# %%
commit_message = "saving icarl training results" # @param {type:"string"}
# !git remote set-url origin https://{token}@github.com/esthy13/cil-intrusion-detection.git
# !git add .
# !git status
# !git commit -m "$commit_message"
# !git push origin main
