# %% [markdown]
# # DER
# Dark Experience - catastrophic experience forgetting

# %% [markdown]
# ## 1. Downloading dataset

# %%
import pandas as pd

links = pd.read_csv("dataset_links.csv")
url_2017 = links[["name"]=="CIC-IDS-2017"][1]
print(url_2017)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 links = pd.read_csv("dataset_links.csv")
#       4 url_2017 = links[["name"]=="CIC-IDS-2017"][1]
#
# ModuleNotFoundError: No module named 'pandas'
